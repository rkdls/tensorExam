# %%
import tensorflow as tf
import pickle
import os
import shutil
import tempfile
import datetime
from glob import iglob
import time
# import attention
from collections import deque
import pickle
import pyreader
import numpy as np
import sys
import csv
from batchmake import Batcher
import astwalker
import ast
import tokenize
import pprint
from io import StringIO

# %%
datas= 'data_samples/'
subdirectories = [os.path.join(datas,o) for o in os.listdir(datas) if os.path.isdir(os.path.join(datas,o))]
python_files = [(directory, [y for x in os.walk(directory) for y in iglob(os.path.join(x[0], '*.py'))])
                for directory in subdirectories]

# %%
def get_source_tree(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        fstr = f.read()
    fstr = fstr.replace('\r\n', '\n').replace('\r', '\n')
    if not fstr.endswith('\n'):
        fstr += '\n'
    return fstr, ast.parse(fstr, filename=filename)

# %%
files = [f[1] for f in python_files]
p_files = []
for f in files:
    for j in f :
        p_files.append(j)
print(len(p_files))
# Out:
# 728

# %%
tokenizer = tf.contrib.keras.preprocessing.text.Tokenizer()
for python_file in p_files:
    
    try:
        source, tree = get_source_tree(python_file)
        word_seq = tf.contrib.keras.preprocessing.text.text_to_word_sequence(source)
        tokenizer.fit_on_texts(word_seq)
    except:
        print('error when parsing ',python_file)
        continue
# tokens = tokenize.generate_tokens(StringIO(source).readline)
# print(source)
# Out:
# error when parsing  data_samples/521xueweihan\HelloGitHub\script\github_bot\github_bot.py
# error when parsing  data_samples/7sDream\zhihu-py3\example\analyze_user.py
# error when parsing  data_samples/7sDream\zhihu-py3\zhihu\client.py
# error when parsing  data_samples/7sDream\zhihu-py3\zhihu\common.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\api.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\async.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\sessions.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\packages\urllib3\connectionpool.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\packages\urllib3\poolmanager.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\packages\urllib3\request.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCA\fosho\requests\packages\urllib3\response.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\api.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\async.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\sessions.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\packages\urllib3\connectionpool.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\packages\urllib3\poolmanager.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\packages\urllib3\request.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\ELCO\fosho\requests\packages\urllib3\response.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\EXBA\Mexeggs\argparse.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\EXBA\scapy\asn1\mib.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\EXBA\scapy\layers\llmnr.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\EXBA\scapy\layers\tftp.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\EXBA\scapy\modules\queso.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Firewall\EXPLOITS\EXBA\scapy\modules\voip.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\Linux\bin\menu.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\fuzzbunch\exception.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\audit.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\commands.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\dir.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\drivers.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\eventlogedit.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\eventlogfilter.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\groups.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\netmap.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\passworddump.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\performance.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\processes.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\redirect.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\registryquery.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\run.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\users.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\cmd\__init__.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\data\packages.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\files\dirs.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\networking\connections.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\networking\netmap.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\networking\route.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\processes\processinfo.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\project\__init__.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\psp\actions.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\psp\__init__.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\security\__init__.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\survey\engine\etreehandler.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Ops\PyScripts\lib\ops\system\registry.py
# error when parsing  data_samples/adamcaudill\EquationGroupLeak\windows\Resources\Python\Override\Lib\multiprocessing\__init__.py
# error when parsing  data_samples/affinelayer\pix2pix-tensorflow\tools\tfimage.py
# error when parsing  data_samples/aio-libs\aiohttp\setup.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\client.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\client_proto.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\connector.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\formdata.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\helpers.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\multipart.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\payload.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\payload_streamer.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\pytest_plugin.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\resolver.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\signals.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\streams.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\test_utils.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web_fileresponse.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web_middlewares.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web_protocol.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web_request.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web_server.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\web_urldispatcher.py
# error when parsing  data_samples/aio-libs\aiohttp\aiohttp\worker.py
# error when parsing  data_samples/aio-libs\aiohttp\docs\conf.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_client_functional_oldstyle.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_client_request.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_client_session.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_flowcontrol_streams.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_helpers.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_multipart.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_proxy_functional.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_run_app.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_signals.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_streams.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_web_application.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_web_protocol.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_web_response.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_web_sendfile_functional.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_web_websocket.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\test_web_websocket_functional.py
# error when parsing  data_samples/aio-libs\aiohttp\tests\autobahn\client.py

# %%
# print(tokenizer.word_counts)
# tokenizer.word_docs['import']
# tokenizer.word_index['import']
tokenizer.index_docs
word_counts = tokenizer.word_counts
word_counts = sorted(word_counts.items(), key=lambda x:x[1], reverse=True)
word_counts = [word for word in word_counts if word[1] >10]
# word_counts = [word for word in word_counts]
word_seq
# Out:
# ['import',
#  'asyncio',
#  'import',
#  'logging',
#  'from',
#  'aiohttp',
#  'import',
#  'web',
#  'asyncio',
#  'coroutine',
#  'def',
#  'function2571',
#  'arg119',
#  'var3601',
#  'web',
#  'websocketresponse',
#  'autoclose',
#  'false',
#  'var1544',
#  'var1511',
#  'var3601',
#  'can',
#  'start',
#  'arg119',
#  'if',
#  'not',
#  'var1544',
#  'return',
#  'web',
#  'httpbadrequest',
#  'yield',
#  'from',
#  'var3601',
#  'prepare',
#  'arg119',
#  'while',
#  'true',
#  'var188',
#  'yield',
#  'from',
#  'var3601',
#  'receive',
#  'if',
#  'var188',
#  'type',
#  'web',
#  'wsmsgtype',
#  'text',
#  'var3601',
#  'send',
#  'str',
#  'var188',
#  'data',
#  'elif',
#  'var188',
#  'type',
#  'web',
#  'wsmsgtype',
#  'binary',
#  'var3601',
#  'send',
#  'bytes',
#  'var188',
#  'data',
#  'elif',
#  'var188',
#  'type',
#  'web',
#  'wsmsgtype',
#  'close',
#  'yield',
#  'from',
#  'var3601',
#  'close',
#  'break',
#  'else',
#  'break',
#  'return',
#  'var3601',
#  'asyncio',
#  'coroutine',
#  'def',
#  'function1191',
#  'arg1043',
#  'var4513',
#  'web',
#  'application',
#  'var4513',
#  'router',
#  'add',
#  'route',
#  "'get'",
#  "'",
#  "'",
#  'function2571',
#  'var927',
#  'var4513',
#  'make',
#  'handler',
#  'var700',
#  'yield',
#  'from',
#  'arg1043',
#  'create',
#  'server',
#  'var927',
#  "'127",
#  '0',
#  '0',
#  "1'",
#  '9001',
#  'print',
#  "'server",
#  'started',
#  'at',
#  'http',
#  '127',
#  '0',
#  '0',
#  '1',
#  "9001'",
#  'return',
#  'var4513',
#  'var700',
#  'var927',
#  'asyncio',
#  'coroutine',
#  'def',
#  'function663',
#  'arg1578',
#  'arg1648',
#  'arg472',
#  'arg1648',
#  'close',
#  'yield',
#  'from',
#  'arg472',
#  'finish',
#  'connections',
#  'yield',
#  'from',
#  'arg1648',
#  'wait',
#  'closed',
#  'if',
#  'name',
#  "'",
#  'main',
#  "'",
#  'var3709',
#  'asyncio',
#  'get',
#  'event',
#  'loop',
#  'logging',
#  'basicconfig',
#  'level',
#  'logging',
#  'debug',
#  'format',
#  "'",
#  'asctime',
#  's',
#  'levelname',
#  's',
#  'message',
#  "s'",
#  'var3709',
#  'asyncio',
#  'get',
#  'event',
#  'loop',
#  'var4328',
#  'var775',
#  'var1082',
#  'var3709',
#  'run',
#  'until',
#  'complete',
#  'function1191',
#  'var3709',
#  'try',
#  'var3709',
#  'run',
#  'forever',
#  'except',
#  'keyboardinterrupt',
#  'var3709',
#  'run',
#  'until',
#  'complete',
#  'function663',
#  'var4328',
#  'var775',
#  'var1082']

# %%
# print(word_counts)
print(tokenizer.word_index[word_counts[7][0]])
# tokenizer.word_index
# Out:
# 8

# %%
tokenizer.texts_to_sequences(['import','self'])
# Out:
# [[9], [2]]

# %%
# reserved_keword = ('<PAD>':0, '<UNK>':1, '<GO>':2, '<EOS>':3 )
# word_counts.insert(1, reserved_keword)
# word_counts.extend(reserved_keword)

# word_counts.remove('<PAD>')
# word_counts.remove({'<EOS>': 3, '<GO>': 2, '<PAD>': 0, '<UNK>': 1})
# word_counts.pop(0)
pad_token, pad_id = "§PAD§", 0
oov_token, oov_id = "§OOV§", 1
indent_token = "§<indent>§"
dedent_token = "§<dedent>§"
number_token = "§NUM§"

word_counts.insert(0,(pad_token,0))
word_counts.insert(1,(oov_token,0))
word_counts.insert(2,('§GO§',0))
word_counts.insert(3,('§EOS§',0))
word_counts.insert(4,(indent_token,0))
word_counts.insert(5,(dedent_token,0))
word_counts.insert(6,(number_token,0))
word_counts.insert(7,('.',0))
word_counts.insert(7,('\n',0))

word_counts
# Out:
# [('§PAD§', 0),
#  ('§OOV§', 0),
#  ('§GO§', 0),
#  ('§EOS§', 0),
#  ('§<indent>§', 0),
#  ('§<dedent>§', 0),
#  ('§NUM§', 0),
#  ("'", 9656),
#  ('self', 8194),
#  ('def', 4605),
#  ('if', 4080),
#  ('return', 3926),
#  ('0', 3811),
#  ('dsz', 3629),
#  ('1', 2817),
#  ('import', 2760),
#  ('from', 2370),
#  ('in', 2174),
#  ('none', 2087),
#  ('n', 2027),
#  ('type', 1777),
#  ('assert', 1747),
#  ('for', 1703),
#  ('tf', 1649),
#  ('x90', 1635),
#  ('144', 1627),
#  ('not', 1618),
#  ('s', 1327),
#  ('is', 1279),
#  ('165', 1233),
#  ('false', 1232),
#  ('opsfield', 1202),
#  ('yield', 1196),
#  ('ops', 1180),
#  ('true', 1133),
#  ('args', 1085),
#  ('get', 1081),
#  ('else', 1061),
#  ("''", 1035),
#  ('mock', 895),
#  ('len', 894),
#  ('print', 874),
#  ('with', 833),
#  ('string', 833),
#  ('asyncio', 828),
#  ('path', 808),
#  ('os', 794),
#  ('data', 794),
#  ('int', 777),
#  ('name', 767),
#  ('add', 760),
#  ('x00', 753),
#  ('2', 751),
#  ('class', 748),
#  ('echo', 740),
#  ('ui', 712),
#  ('the', 688),
#  ('coroutine', 686),
#  ('append', 681),
#  ('cmd', 657),
#  ('and', 643),
#  ('a', 614),
#  ('to', 609),
#  ('web', 583),
#  ('as', 555),
#  ("s'", 554),
#  ('var1967', 540),
#  ('var4654', 538),
#  ('or', 530),
#  ('try', 489),
#  ('run', 482),
#  ('value', 479),
#  ('elif', 476),
#  ('opsclass', 458),
#  ('except', 457),
#  ('49', 446),
#  ('url', 436),
#  ('join', 433),
#  ('4', 432),
#  ('file', 431),
#  ('str', 426),
#  ("n'", 423),
#  ('set', 410),
#  ('init', 406),
#  ('text', 406),
#  ('close', 394),
#  ('loop', 389),
#  ('list', 386),
#  ('re', 384),
#  ('dszobject', 382),
#  ("'get'", 381),
#  ('r', 378),
#  ('aiohttp', 372),
#  ('of', 367),
#  ('sys', 355),
#  ('headers', 354),
#  ('status', 348),
#  ('error', 343),
#  ('3', 336),
#  ('255', 320),
#  ('raise', 317),
#  ('dict', 317),
#  ('post', 313),
#  ('pytest', 312),
#  ('range', 301),
#  ('10', 288),
#  ('write', 285),
#  ('shared', 285),
#  ('function1737', 281),
#  ('shape', 281),
#  ('find', 277),
#  ('control', 276),
#  ('application', 275),
#  ("'http", 274),
#  ('bool', 270),
#  ('variable', 269),
#  ('nn', 265),
#  ('5', 257),
#  ('response', 254),
#  ('default', 250),
#  ('9', 248),
#  ('definitions', 247),
#  ('router', 247),
#  ('read', 245),
#  ('key', 244),
#  ('datetime', 238),
#  ('d', 235),
#  ('help', 233),
#  ("'name'", 232),
#  ('200', 231),
#  ('assertequal', 230),
#  ('np', 228),
#  ('content', 219),
#  ('cookie', 215),
#  ('lower', 213),
#  ("'type'", 213),
#  ('open', 212),
#  ('http', 212),
#  ('domain', 212),
#  ('version', 210),
#  ('test', 208),
#  ('pass', 207),
#  ('session', 205),
#  ('hdrs', 205),
#  ('socket', 202),
#  ('split', 200),
#  ('property', 200),
#  ('format', 199),
#  ('on', 199),
#  ('time', 198),
#  ('parse', 195),
#  ('isinstance', 195),
#  ('safeprint', 195),
#  ('exception', 190),
#  ('json', 189),
#  ('answer', 187),
#  ('8', 187),
#  ('single', 186),
#  ('route', 185),
#  ('be', 182),
#  ('question', 181),
#  ('argument', 181),
#  ('target', 180),
#  ('function742', 180),
#  ('match', 179),
#  ('author', 177),
#  ('info', 177),
#  ('called', 177),
#  ('connection', 174),
#  ('while', 170),
#  ('main', 169),
#  ('dszcommandobject', 169),
#  ('function1233', 169),
#  ('feed', 167),
#  ('train', 166),
#  ('com', 165),
#  ('create', 165),
#  ('strip', 164),
#  ('6', 160),
#  ('raises', 159),
#  ('id', 158),
#  ('future', 155),
#  ('request', 154),
#  ('exists', 153),
#  ('this', 152),
#  ('make', 150),
#  ('function635', 149),
#  ('ip', 146),
#  ('cache', 146),
#  ('project', 145),
#  ('header', 143),
#  ('continue', 142),
#  ('client', 141),
#  ('all', 139),
#  ('class82', 139),
#  ('face', 139),
#  ('size', 138),
#  ('c', 138),
#  ('248', 138),
#  ('function146', 138),
#  ('dest', 137),
#  ('protocol', 135),
#  ('host', 135),
#  ('max', 135),
#  ('env', 135),
#  ('query', 134),
#  ('trch', 133),
#  ('soup', 132),
#  ('random', 132),
#  ('survey', 132),
#  ('20', 131),
#  ('rtype', 130),
#  ('object', 130),
#  ('lambda', 130),
#  ('lp', 130),
#  ('16', 128),
#  ('wsmsgtype', 126),
#  ('zhihu', 125),
#  ('use', 125),
#  ('break', 125),
#  ('you', 125),
#  ('point', 125),
#  ("8'", 124),
#  ('7', 124),
#  ('t', 124),
#  ('patch', 123),
#  ('191', 122),
#  ('lineobj', 120),
#  ('line', 119),
#  ('184', 119),
#  ('image', 118),
#  ('load', 117),
#  ('tcp', 117),
#  ("1'", 116),
#  ('payload', 116),
#  ('command', 116),
#  ("'ops", 115),
#  ("'aiohttp", 115),
#  ('valueerror', 114),
#  ('param', 114),
#  ('encode', 114),
#  ("'content", 114),
#  ('x1b', 114),
#  ('history', 113),
#  ('function2080', 112),
#  ('proxy', 110),
#  ("'value'", 110),
#  ('execute', 110),
#  ("'utf", 109),
#  ('num', 109),
#  ('release', 109),
#  ('dir', 108),
#  ('normal', 108),
#  ('timedelta', 108),
#  ('startswith', 107),
#  ('windows', 107),
#  ('flag', 107),
#  ('record', 107),
#  ('attribute501', 107),
#  ("b'", 106),
#  ('output', 106),
#  ('good', 106),
#  ('var1707', 105),
#  ('scope', 105),
#  ("name'", 104),
#  ('system', 103),
#  ("'id'", 103),
#  ('80', 103),
#  ('seconds', 103),
#  ('datastore', 103),
#  ('send', 102),
#  ('example', 102),
#  ('input', 102),
#  ('235', 102),
#  ("'port'", 101),
#  ('matmul', 101),
#  ('check', 100),
#  ("'time'", 100),
#  ('warning', 100),
#  ("'first", 100),
#  ('group', 99),
#  ('var4266', 99),
#  ('maxage', 99),
#  ('function2564', 99),
#  ('body', 98),
#  ('function145', 98),
#  ('websocket', 98),
#  ("com'", 97),
#  ('function', 97),
#  ('code', 97),
#  ('var3926', 97),
#  ('log', 97),
#  ("org'", 97),
#  ('mocked', 97),
#  ('pprint', 96),
#  ('www', 95),
#  ('closed', 95),
#  ('173', 95),
#  ('parameter', 95),
#  ('must', 94),
#  ('action', 94),
#  ('truncated', 94),
#  ('attribute1230', 93),
#  ('attribute1392', 93),
#  ('method', 93),
#  ('util', 93),
#  ("'a'", 92),
#  ('off', 92),
#  ('length', 91),
#  ('second', 91),
#  ('encoding', 91),
#  ('64', 90),
#  ('connect', 90),
#  ('addstr', 90),
#  ('arg738', 90),
#  ("size'", 90),
#  ('helpers', 90),
#  ('runtimeerror', 89),
#  ("cookie'", 89),
#  ("b''", 89),
#  ('accuracy', 89),
#  ("path'", 89),
#  ('attribute166', 88),
#  ('resolve', 88),
#  ('keys', 87),
#  ('repr', 87),
#  ('script', 87),
#  ('eval', 86),
#  ('python', 86),
#  ('no', 86),
#  ('handler', 86),
#  ('zeros', 86),
#  ('config', 85),
#  ('236', 85),
#  ('12', 84),
#  ("'test", 84),
#  ('cookies', 84),
#  ('by', 84),
#  ('event', 84),
#  ("address'", 84),
#  ('getdszcommand', 84),
#  ('function1158', 84),
#  ('constant', 84),
#  ('span', 83),
#  ('timeout', 83),
#  ('menu', 83),
#  ('softmax', 83),
#  ('ws', 83),
#  ('unittest', 82),
#  ('128', 82),
#  ('search', 81),
#  ('l', 81),
#  ('port', 81),
#  ('collection', 80),
#  ('var2598', 80),
#  ('message', 80),
#  ('files', 80),
#  ('181', 80),
#  ('mask', 80),
#  ('i', 79),
#  ('x04', 79),
#  ('201', 79),
#  ("dll'", 79),
#  ('istr', 79),
#  ('100', 78),
#  ('tag', 78),
#  ('bytes', 78),
#  ('b', 78),
#  ('192', 78),
#  ('server', 78),
#  ('prompt', 78),
#  ('complete', 78),
#  ('batch', 78),
#  ('expected', 77),
#  ("d'", 77),
#  ("'div'", 77),
#  ('option', 77),
#  ("third'", 77),
#  ('float32', 77),
#  ('software', 76),
#  ("'data'", 76),
#  ('upper', 76),
#  ('187', 76),
#  ('250', 76),
#  ('216', 75),
#  ('db', 75),
#  ('00', 74),
#  ('251', 74),
#  ('at', 74),
#  ('attribute1140', 74),
#  ('result', 74),
#  ('glob', 74),
#  ('hive', 74),
#  ("'nt", 74),
#  ('zip', 73),
#  ('m', 73),
#  ('that', 73),
#  ('exceptions', 73),
#  ('252', 73),
#  ('until', 73),
#  ('177', 73),
#  ('plugin', 73),
#  ('reason', 72),
#  ('should', 72),
#  ('curses', 72),
#  ("u'", 72),
#  ('137', 72),
#  ('66', 72),
#  ('233', 72),
#  ('labels', 72),
#  ('decode', 71),
#  ("id'", 71),
#  ("type'", 71),
#  ('address', 71),
#  ('any', 71),
#  ('x01', 71),
#  ('205', 71),
#  ("'path'", 71),
#  ("'127", 70),
#  ('249', 70),
#  ('186', 70),
#  ('164', 70),
#  ('var2249', 69),
#  ('global', 69),
#  ('attribute2150', 69),
#  ('logging', 69),
#  ('pickle', 69),
#  ('185', 69),
#  ('243', 69),
#  ('232', 69),
#  ("'description'", 69),
#  ('task', 69),
#  ('recognition', 69),
#  ('utils', 68),
#  ('del', 68),
#  ('update', 68),
#  ('are', 68),
#  ("195'", 68),
#  ('x04üó¤é', 68),
#  ('94', 68),
#  ('found', 67),
#  ("txt'", 67),
#  ('mnist', 67),
#  ('eof', 67),
#  ('unicode', 66),
#  ('save', 66),
#  ('163', 66),
#  ('loss', 66),
#  ('receive', 66),
#  ('var507', 65),
#  ('it', 65),
#  ('compile', 65),
#  ('process', 65),
#  ('var3749', 65),
#  ('transport', 65),
#  ('var1301', 65),
#  ('profiles', 65),
#  ('graph', 65),
#  ('scan', 64),
#  ('readlinetextbuffer', 64),
#  ('function1139', 64),
#  ('an', 63),
#  ('scapy', 63),
#  ('stddev', 63),
#  ("'https", 62),
#  ('11', 62),
#  ('will', 62),
#  ('36', 62),
#  ('layers', 62),
#  ("'protocol'", 62),
#  ('dtype', 62),
#  ('coro', 62),
#  ('number', 61),
#  ("'application", 61),
#  ('exit', 61),
#  ('resp', 61),
#  ("'registryquery", 61),
#  ('step', 61),
#  ("num'", 60),
#  ('19', 60),
#  ('has', 60),
#  ('subdomains', 60),
#  ('age', 60),
#  ('settings', 60),
#  ('column', 59),
#  ("'data", 59),
#  ("'zm", 59),
#  ('items', 59),
#  ('filter', 59),
#  ('argv', 59),
#  ('var617', 59),
#  ('15', 59),
#  ('placeholder', 59),
#  ('dirname', 58),
#  ('start', 58),
#  ('valid', 58),
#  ('attribute847', 58),
#  ('attribute882', 58),
#  ('call', 58),
#  ('1024', 58),
#  ('description', 57),
#  ('params', 57),
#  ("0'", 57),
#  ('packet', 57),
#  ('53', 57),
#  ('var4242', 57),
#  ('clientresponse', 57),
#  ('baseconnector', 57),
#  ('upvote', 56),
#  ('mode', 56),
#  ('topic', 56),
#  ('replace', 56),
#  ("'unknown'", 56),
#  ('traceback', 56),
#  ('x8b', 56),
#  ('function1004', 56),
#  ('app', 56),
#  ('filename', 55),
#  ('y', 55),
#  ("'no", 55),
#  ('side', 55),
#  ("'0'", 55),
#  ('inet', 55),
#  ('values', 55),
#  ('frame', 55),
#  ('170', 55),
#  ('extra', 55),
#  ('prepare', 55),
#  ('var4192', 54),
#  ('af', 54),
#  ('var3169', 54),
#  ('mark', 54),
#  ('summary', 54),
#  ('cork', 54),
#  ('fixture', 54),
#  ('module', 53),
#  ('30', 53),
#  ('copy', 53),
#  ('warn', 53),
#  ("'rb'", 52),
#  ('api', 52),
#  ("'href'", 52),
#  ('loads', 52),
#  ('dns', 52),
#  ('simplecookie', 52),
#  ("'tkinter", 52),
#  ('bold', 52),
#  ("'l'", 52),
#  ('var2295', 52),
#  ('fa', 52),
#  ('var2728', 51),
#  ('sleep', 51),
#  ('xml', 51),
#  ('var1973', 51),
#  ("data'", 51),
#  ('bind', 51),
#  ('targetid', 51),
#  ('cimultidict', 51),
#  ('shutil', 50),
#  ('var2625', 50),
#  ('py', 50),
#  ("x80'", 50),
#  ('x10', 50),
#  ("redirect'", 50),
#  ('28', 50),
#  ('var2844', 50),
#  ('extend', 50),
#  ('float', 50),
#  ("'user'", 50),
#  ('function1107', 50),
#  ('scansweep', 50),
#  ('user', 49),
#  ("'1'", 49),
#  ('getattr', 49),
#  ('charset', 49),
#  ("'post'", 49),
#  ('reduce', 49),
#  ('buffer', 49),
#  ("'localhost'", 49),
#  ('upgrade', 49),
#  ('function2574', 49),
#  ('var684', 49),
#  ('var3652', 48),
#  ("'test'", 48),
#  ('map', 48),
#  ("'host'", 48),
#  ('urlparse', 48),
#  ("'text", 48),
#  ('ssl', 48),
#  ('systempath', 48),
#  ('f0', 48),
#  ("'layer", 48),
#  ('1f', 48),
#  ("'notmnist", 48),
#  ('acquired', 48),
#  ('argumentparser', 47),
#  ('findall', 47),
#  ('exc', 47),
#  ('var791', 47),
#  ('do', 47),
#  ('85', 47),
#  ('tcpconnector', 47),
#  ('end', 46),
#  ('kasperskylab', 46),
#  ('var4483', 46),
#  ('dropout', 46),
#  ("'patch", 46),
#  ("'r'", 45),
#  ('var1239', 45),
#  ('failed', 45),
#  ('one', 45),
#  ('super', 45),
#  ('endswith', 45),
#  ('enter', 45),
#  ('local', 45),
#  ('60', 45),
#  ('function1720', 45),
#  ("sum'", 45),
#  ('conns', 45),
#  ('var1645', 44),
#  ('arg210', 44),
#  ('optionparser', 44),
#  ('var3644', 44),
#  ('field', 44),
#  ('redirect', 44),
#  ('131', 44),
#  ('arg2010', 44),
#  ('where', 44),
#  ('attribute1936', 44),
#  ('clientsession', 44),
#  ('clientrequest', 44),
#  ('var1808', 43),
#  ('h', 43),
#  ('argparse', 43),
#  ('var3458', 43),
#  ("'set", 43),
#  ("'store", 43),
#  ("'ip'", 43),
#  ("xml'", 43),
#  ("key'", 43),
#  ("'could", 43),
#  ('registry', 43),
#  ('common', 42),
#  ('1000', 42),
#  ('e', 42),
#  ('typeerror', 42),
#  ('dumps', 42),
#  ('clear', 42),
#  ('acquire', 42),
#  ('var2466', 42),
#  ("'failed", 42),
#  ('disprow', 42),
#  ("'store'", 42),
#  ("'max", 42),
#  ('new', 42),
#  ('var434', 42),
#  ('subprocess', 42),
#  ('var249', 42),
#  ('var3533', 42),
#  ('var1223', 42),
#  ('relu', 42),
#  ('effect', 42),
#  ('importerror', 41),
#  ('beautifulsoup', 41),
#  ('title', 41),
#  ('next', 41),
#  ("r'", 41),
#  ('multiprocessing', 41),
#  ('required', 41),
#  ("file'", 41),
#  ("true'", 41),
#  ('your', 41),
#  ("'broadcast'", 41),
#  ('229', 41),
#  ('172', 41),
#  ('running', 41),
#  ('var1404', 41),
#  ('kaspersky', 41),
#  ('tensorflow', 41),
#  ('model', 41),
#  ('cleanup', 41),
#  ('requests', 40),
#  ('25', 40),
#  ('var3007', 40),
#  ('finally', 40),
#  ('item', 40),
#  ('x', 40),
#  ('var3085', 40),
#  ('keyerror', 40),
#  ('platform', 40),
#  ('arg2252', 40),
#  ('maxx', 40),
#  ('move', 40),
#  ('struct', 40),
#  ('x06', 40),
#  ('io', 40),
#  ("request'", 40),
#  ('raw', 40),
#  ('208', 40),
#  ('limit', 40),
#  ('var1145', 40),
#  ('47', 40),
#  ('function1058', 40),
#  ("exe'", 40),
#  ('array', 40),
#  ("'software", 40),
#  ("to'", 40),
#  ('connector', 40),
#  ('chunked', 40),
#  ('collections', 39),
#  ("'invalid", 39),
#  ('iterable', 39),
#  ('function539', 39),
#  ('which', 39),
#  ('network', 39),
#  ('getvalue', 39),
#  ('count', 39),
#  ('var52', 39),
#  ('microsoft', 39),
#  ('var4553', 39),
#  ('cl', 39),
#  ('var290', 38),
#  ('follow', 38),
#  ("'top", 38),
#  ('location', 38),
#  ('32', 38),
#  ('randint', 38),
#  ("'you", 38),
#  ("'y'", 38),
#  ('current', 38),
#  ('compression', 38),
#  ("'ok'", 38),
#  ('zlib', 38),
#  ('160', 38),
#  ('index', 38),
#  ('variables', 38),
#  ("'getvalue'", 38),
#  ("'setvalue'", 38),
#  ('runex', 38),
#  ('var2571', 38),
#  ('function856', 38),
#  ('var904', 37),
#  ('anonymous', 37),
#  ('verbose', 37),
#  ('arg436', 37),
#  ('arg2276', 37),
#  ('var2843', 37),
#  ("'n'", 37),
#  ('var3787', 37),
#  ('var1840', 37),
#  ("required'", 37),
#  ("'ë", 37),
#  ('var1569', 37),
#  ('function1949', 37),
#  ('var265', 37),
#  ('volatile', 37),
#  ('162', 37),
#  ('197', 37),
#  ('var4346', 37),
#  ('function2364', 37),
#  ('function214', 37),
#  ('var287', 37),
#  ('static', 37),
#  ('handle', 36),
#  ('sock', 36),
#  ('debug', 36),
#  ('127', 36),
#  ('arg1357', 36),
#  ('addr', 36),
#  ('formdata', 36),
#  ('var988', 36),
#  ('fields', 36),
#  ("value'", 36),
#  ("'please", 36),
#  ('attribute2081', 36),
#  ('setvalue', 36),
#  ("'target'", 36),
#  ('var929', 36),
#  ("b'get", 36),
#  ("xsrf'", 35),
#  ('var1693', 35),
#  ('profile', 35),
#  ('var4405', 35),
#  ('var1841', 35),
#  ('can', 35),
#  ('stream', 35),
#  ("'get", 35),
#  ('into', 35),
#  ('var3805', 35),
#  ('chr', 35),
#  ('pack', 35),
#  ('only', 35),
#  ('auth', 35),
#  ('var3380', 35),
#  ('class436', 35),
#  ("'file'", 35),
#  ('function130', 35),
#  ('var1174', 35),
#  ('var1155', 35),
#  ('129', 35),
#  ('x14', 35),
#  ("'191", 35),
#  ('var3331', 35),
#  ('numpy', 35),
#  ('getstring', 35),
#  ('mac', 35),
#  ('dataset', 35),
#  ('environ', 34),
#  ('html', 34),
#  ('refresh', 34),
#  ('p', 34),
#  ('var2139', 34),
#  ('attribute1011', 34),
#  ('var3395', 34),
#  ("f'", 34),
#  ('attribute673', 34),
#  ('maxy', 34),
#  ('attribute1000', 34),
#  ('flags', 34),
#  ('setting', 34),
#  ('connections', 34),
#  ('environment', 34),
#  ('var3751', 34),
#  ("'139", 34),
#  ("'184", 34),
#  ('x80ë', 34),
#  ('x14¿', 34),
#  ('t1é±', 34),
#  ('x0c', 34),
#  ('ëìèøÿÿÿ1à', 34),
#  ("ã'", 34),
#  ('xa0¥¥¥1úí', 34),
#  ("'235", 34),
#  ("128'", 34),
#  ('x081é±', 34),
#  ('var3862', 34),
#  ('cursor', 34),
#  ('arg453', 34),
#  ('var3452', 34),
#  ('var3379', 34),
#  ('function2118', 34),
#  ('function596', 34),
#  ("'local", 34),
#  ('var3255', 34),
#  ('cfg', 34),
#  ("'minibatch", 34),
#  ('nodelay', 34),
#  ('httpok', 34),
#  ('packages', 33),
#  ('acttype', 33),
#  ('sum', 33),
#  ("'w'", 33),
#  ("jpg'", 33),
#  ('date', 33),
#  ('var1828', 33),
#  ("t'", 33),
#  ("'text'", 33),
#  ('arg1404', 33),
#  ("'file", 33),
#  ('base64', 33),
#  ('before', 33),
#  ('101', 33),
#  ('setitem', 33),
#  ("'version'", 33),
#  ("2'", 33),
#  ('class44', 33),
#  ('asn1f', 33),
#  ('var4070', 33),
#  ("'date'", 33),
#  ('var4325', 33),
#  ('mean', 33),
#  ('sec', 33),
#  ('var363', 33),
#  ("'some'", 33),
#  ("'0", 32),
#  ('var2430', 32),
#  ('org', 32),
#  ('var559', 32),
#  ('var2427', 32),
#  ('enable', 32),
#  ('like', 32),
#  ('first', 32),
#  ('arg855', 32),
#  ('optparse', 32),
#  ('f', 32),
#  ('kwargs', 32),
#  ('attribute1013', 32),
#  ('resource', 32),
#  ("x00'", 32),
#  ('var1671', 32),
#  ("'not", 32),
#  ('var1102', 32),
#  ('var699', 32),
#  ('intfield', 32),
#  ('getfiles', 32),
#  ('pyreadline', 32),
#  ("'local'", 32),
#  ('function554', 32),
#  ('function1068', 32),
#  ('function614', 32),
#  ('checks', 32),
#  ('recordtooluse', 32),
#  ('systemroot', 32),
#  ('fileitem', 32),
#  ('done', 32),
#  ('function1712', 32),
#  ('protected', 32),
#  ('class157', 32),
#  ('maxpool2d', 32),
#  ('50', 31),
#  ('more', 31),
#  ('top', 31),
#  ('last', 31),
#  ("'location'", 31),
#  ('function2076', 31),
#  ('var3434', 31),
#  ('threading', 31),
#  ('information', 31),
#  ('x80', 31),
#  ('var4637', 31),
#  ('tuple', 31),
#  ('var2559', 31),
#  ('var223', 31),
#  ('88', 31),
#  ('var2332', 31),
#  ('var107', 31),
#  ('var2445', 31),
#  ('arg1795', 31),
#  ('var3141', 31),
#  ('monitor', 31),
#  ('var4408', 31),
#  ("'enabled'", 31),
#  ("'system", 31),
#  ('assign', 31),
#  ('writer', 31),
#  ('minimize', 31),
#  ('remove', 30),
#  ("json'", 30),
#  ('comment', 30),
#  ('sort', 30),
#  ('31', 30),
#  ('enumerate', 30),
#  ('var2121', 30),
#  ('var1227', 30),
#  ('var4020', 30),
#  ('var3148', 30),
#  ('hasattr', 30),
#  ('404', 30),
#  ('attribute1123', 30),
#  ('urllib', 30),
#  ('ctypes', 30),
#  ('stdout', 30),
#  ('optional', 30),
#  ('dispcol', 30),
#  ('var1595', 30),
#  ("error'", 30),
#  ('arg1369', 30),
#  ('var2916', 30),
#  ('udp', 30),
#  ("protocol'", 30),
#  ("'pid'", 30),
#  ('var104', 30),
#  ('var1124', 30),
#  ('var174', 30),
#  ("'select", 30),
#  ("'enter", 30),
#  ("'num", 30),
#  ('normpath', 30),
#  ('var3040', 30),
#  ("'hostname'", 30),
#  ('var2098', 30),
#  ('maybe', 30),
#  ('var296', 30),
#  ("'depth'", 30),
#  ('learning', 30),
#  ('subapp', 30),
#  ("py'", 29),
#  ('var1348', 29),
#  ('element', 29),
#  ("'http'", 29),
#  ('delete', 29),
#  ("'msg'", 29),
#  ('using', 29),
#  ('var3726', 29),
#  ('14', 29),
#  ('var2000', 29),
#  ('var1042', 29),
#  ('var4293', 29),
#  ('models', 29),
#  ('see', 29),
#  ('500', 29),
#  ('behavior', 29),
#  ('var2931', 29),
#  ('ord', 29),
#  ('arg1730', 29),
#  ('var922', 29),
#  ('textcolor', 29),
#  ('success', 29),
#  ("'b'", 29),
#  ('139', 29),
#  ...]

# %%
word_counts[0]
# Out:
# ('§PAD§', 0)

# %%
with open('vocab.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow
    for word in word_counts[:50000]:
#         writer.writerow([word[0], tokenizer.word_index[word[0]], word[1]])
        writer.writerow([word[0]])
