# %% [markdown]
# # Word2Vec Tutorial

# %%
# %matplotlib inline
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


words = read_data(filename)
print('Data size', len(words))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
def build_dataset(words, vocabulary_size):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3082, 12, 6, 195, 2, 3135, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
dictionary = dict()
for word, _ in count:
    dictionary[word] = len(dictionary)
data = list()
unk_count = 0
for word in words:
    if word in dictionary:
        index = dictionary[word]
    else:
        index = 0  # dictionary['UNK']
        unk_count += 1
    data.append(index)
count[0][1] = unk_count
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
del words  # Hint to reduce memory.

# %% [markdown]
# ## dictionary :dict타입 '단어': 인덱스값
# ## data : words배열에서 각 워드의 인덱스값
# ## count : 가장높은 빈도수로나온 단어,몇번 나왔는지에 대한 튜플로구성된 리스트

# %%
del  count

# %%
data_index = 0
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span): # span 3
        buffer.append(data[data_index]) 
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips): # batchsize//numskips = 4
        target = skip_window  # target label at the center of the buffer 1
        targets_to_avoid = [skip_window] # tarkets_to_avoid = [1]
        for j in range(num_skips): # 2
            while target in targets_to_avoid: #1 in [1]
                target = random.randint(0, span - 1)  # target =  0
            targets_to_avoid.append(target)  # [1,0]
            batch[i * num_skips + j] = buffer[skip_window] # 
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# %%
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
          '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3082 originated -> 5236 anarchism
# 3082 originated -> 12 as
# 12 as -> 3082 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=embed,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  271.167877197
# Nearest to this: classrooms, oracle, orcus, cx, palmas, ensures, emergence, puebla,
# Nearest to the: overfishing, understated, superstitious, mathieu, opportunistic, putney, laboratories, tells,
# Nearest to on: antiseptic, gaddis, add, poids, appropriate, conformations, syntactically, hearth,
# Nearest to eight: symbol, adamantium, fanu, lpc, matters, laoghaire, contextual, forestry,
# Nearest to has: maois, parameters, palazzo, back, nuova, stellar, flooded, tarim,
# Nearest to these: moonshine, cpan, deny, chiao, incest, foreshadow, hird, brook,
# Nearest to over: besson, alas, hemionus, dice, balts, mouths, schema, discrepancy,
# Nearest to called: puebla, crewmembers, dyslexia, crowded, mart, musique, soles, equus,
# Nearest to such: bravo, nineties, disarm, suzanne, kline, erlbaum, desiring, vfr,
# Nearest to nine: musica, tiberius, cena, protestants, fishermen, deep, cooks, unaltered,
# Nearest to up: myanmar, rossetti, transposed, claudine, dvi, subsidies, depicts, adair,
# Nearest to its: edifice, raytheon, negate, palace, grammatical, breach, initiation, katanga,
# Nearest to been: logographic, telophase, lapsed, myrinet, budgeted, clergymen, bombs, backers,
# Nearest to also: seeking, earmarked, tritone, fulfillment, isomer, ape, keith, fourth,
# Nearest to used: ia, marta, training, wahhabi, gauntlets, participates, undemocratic, document,
# Nearest to five: guerrillas, cousteau, typical, last, chivalry, malory, explore, dull,
# Average loss at step  2000 :  113.489338771
# Average loss at step  4000 :  52.3443380046
# Average loss at step  6000 :  33.6814840631
# Average loss at step  8000 :  23.4689896781
# Average loss at step  10000 :  17.7485275145
# Nearest to this: fao, oracle, the, archie, sciences, branden, cup, countries,
# Nearest to the: a, one, and, gland, altenberg, his, UNK, growing,
# Nearest to on: in, and, conformations, of, per, into, army, boat,
# Nearest to eight: zero, nine, archie, six, altenberg, five, one, agave,
# Nearest to has: back, is, paperback, sigma, aberdeen, conditioned, can, flooded,
# Nearest to these: deny, honour, discovered, iii, born, took, incest, designers,
# Nearest to over: edition, var, occupied, transmitted, interviews, five, forest, alas,
# Nearest to called: ultimately, compact, looking, altenberg, mart, crusades, shooting, reversed,
# Nearest to such: tarski, nineties, bond, law, faith, bravo, admiration, lillian,
# Nearest to nine: zero, eight, archie, six, agave, one, gland, bckgr,
# Nearest to up: myanmar, vs, ones, depicts, rotated, focusing, polarized, trials,
# Nearest to its: achilles, palace, whatever, rods, court, which, nascar, the,
# Nearest to been: dependent, omnibus, become, logographic, mission, gauge, hearing, emperor,
# Nearest to also: keith, seeking, fourth, fathers, striking, not, compiled, forced,
# Nearest to used: gb, training, recorded, ia, place, document, existence, kubrick,
# Nearest to five: nine, one, zero, eight, gland, six, two, napalm,
# Average loss at step  12000 :  13.9302169063
# Average loss at step  14000 :  12.0784087054
# Average loss at step  16000 :  9.9931362673
# Average loss at step  18000 :  8.6113096261
# Average loss at step  20000 :  8.01719417298
# Nearest to this: the, it, apatosaurus, epistles, a, dasyprocta, agouti, some,
# Nearest to the: a, dasyprocta, agouti, his, this, one, operatorname, hbox,
# Nearest to on: in, and, at, conformations, into, of, vaccines, boat,
# Nearest to eight: nine, six, zero, five, four, seven, dasyprocta, agouti,
# Nearest to has: is, was, had, hbox, back, have, stellar, paperback,
# Nearest to these: deny, incest, operatorname, iii, sarmatians, agouti, honour, sub,
# Nearest to over: edition, agouti, and, nine, in, alas, operatorname, five,
# Nearest to called: ultimately, compact, looking, crowded, reversed, mart, altenberg, dasyprocta,
# Nearest to such: apologia, circ, nineties, tarski, bituminous, bravo, desiring, dasyprocta,
# Nearest to nine: eight, six, seven, five, zero, agouti, dasyprocta, four,
# Nearest to up: rotated, ones, subsidies, myanmar, rossetti, transposed, spinster, polarized,
# Nearest to its: the, his, their, palace, reorganization, amazonas, achilles, achaeans,
# Nearest to been: become, by, dependent, had, were, omnibus, gauge, who,
# Nearest to also: keith, not, which, seeking, acacia, fathers, dasyprocta, pinky,
# Nearest to used: antwerp, gb, circ, gollancz, recorded, kubrick, document, operatorname,
# Nearest to five: nine, zero, eight, six, four, two, agouti, dasyprocta,
# Average loss at step  22000 :  6.99879438233
# Average loss at step  24000 :  6.81412785435
# Average loss at step  26000 :  6.74168067312
# Average loss at step  28000 :  6.38698628902
# Average loss at step  30000 :  5.9507967267
# Nearest to this: the, it, which, apatosaurus, epistles, amalthea, dasyprocta, agouti,
# Nearest to the: its, this, their, his, agouti, a, dasyprocta, apatosaurus,
# Nearest to on: in, at, into, conformations, and, with, vaccines, first,
# Nearest to eight: nine, six, seven, four, five, zero, three, dasyprocta,
# Nearest to has: is, had, was, have, hbox, circ, back, but,
# Nearest to these: incest, operatorname, deny, agouti, creatures, hamath, sub, destinations,
# Nearest to over: edition, agouti, and, groom, alas, overtime, speedup, operatorname,
# Nearest to called: ultimately, aorta, looking, compact, reversed, crowded, open, and,
# Nearest to such: apologia, nineties, arin, circ, well, bravo, tarski, desiring,
# Nearest to nine: eight, seven, six, five, four, zero, agouti, dasyprocta,
# Nearest to up: subsidies, rotated, ones, stwa, rossetti, transposed, assyria, spinster,
# Nearest to its: the, their, his, palace, amazonas, reorganization, agouti, achaeans,
# Nearest to been: become, by, were, had, dependent, reuptake, be, yet,
# Nearest to also: which, not, keith, reuptake, difranco, dasyprocta, that, fathers,
# Nearest to used: ramps, antwerp, circ, gb, primigenius, participates, recorded, gollancz,
# Nearest to five: six, four, eight, zero, seven, nine, three, two,
# Average loss at step  32000 :  5.96872069633
# Average loss at step  34000 :  5.744329602
# Average loss at step  36000 :  5.8050707072
# Average loss at step  38000 :  5.52004111326
# Average loss at step  40000 :  5.24937992805
# Nearest to this: it, which, the, that, a, apatosaurus, operatorname, epistles,
# Nearest to the: its, a, agouti, his, their, dasyprocta, this, apatosaurus,
# Nearest to on: in, at, conformations, with, into, vaccines, two, beyond,
# Nearest to eight: zero, six, nine, seven, five, four, three, dasyprocta,
# Nearest to has: had, is, was, have, hbox, circ, but, mnr,
# Nearest to these: some, many, all, incest, operatorname, deny, hamath, agouti,
# Nearest to over: edition, and, agouti, overtime, discrepancy, speedup, alas, groom,
# Nearest to called: aorta, looking, vma, reversed, ultimately, compact, crowded, and,
# Nearest to such: well, nineties, apologia, arin, many, circ, bravo, desiring,
# Nearest to nine: eight, seven, zero, six, five, four, three, dasyprocta,
# Nearest to up: subsidies, rotated, ones, rossetti, transposed, stwa, assyria, polarized,
# Nearest to its: their, the, his, amazonas, palace, reorganization, a, agouti,
# Nearest to been: become, were, by, be, had, was, reuptake, dependent,
# Nearest to also: which, not, that, now, dasyprocta, keith, agouti, abet,
# Nearest to used: ramps, antwerp, circ, gb, primigenius, operatorname, dasyprocta, panned,
# Nearest to five: four, six, eight, three, zero, seven, two, nine,
# Average loss at step  42000 :  5.37940230155
# Average loss at step  44000 :  5.24320035613
# Average loss at step  46000 :  5.22596279263
# Average loss at step  48000 :  5.22490391028
# Average loss at step  50000 :  5.01748430848
# Nearest to this: it, which, the, that, a, operatorname, dasyprocta, some,
# Nearest to the: its, their, his, a, this, kapoor, agouti, dasyprocta,
# Nearest to on: in, at, two, conformations, vaccines, beyond, dasyprocta, mishnayot,
# Nearest to eight: six, nine, seven, five, four, zero, three, dasyprocta,
# Nearest to has: had, is, was, have, four, hbox, circ, mnr,
# Nearest to these: some, many, several, operatorname, three, all, such, incest,
# Nearest to over: three, edition, agouti, alas, speedup, four, overtime, operatorname,
# Nearest to called: and, aorta, vma, dasyprocta, reversed, compact, disability, looking,
# Nearest to such: well, nineties, many, apologia, arin, these, circ, bravo,
# Nearest to nine: eight, six, seven, zero, five, dasyprocta, agouti, four,
# Nearest to up: subsidies, rotated, transposed, stwa, them, ones, him, rossetti,
# Nearest to its: their, the, his, amazonas, agouti, palace, reorganization, this,
# Nearest to been: become, were, by, be, had, was, reuptake, yet,
# Nearest to also: which, now, not, often, that, it, never, kapoor,
# Nearest to used: ramps, antwerp, circ, primigenius, panned, operatorname, ia, dasyprocta,
# Nearest to five: four, six, three, eight, seven, zero, two, agouti,
# Average loss at step  52000 :  5.05454168332
# Average loss at step  54000 :  5.21083853531
# Average loss at step  56000 :  5.05344008899
# Average loss at step  58000 :  5.04645928478
# Average loss at step  60000 :  4.93301774311
# Nearest to this: it, which, the, that, a, dasyprocta, operatorname, mishnayot,
# Nearest to the: agouti, its, dasyprocta, their, kapoor, this, a, apatosaurus,
# Nearest to on: in, at, conformations, ursus, beyond, into, vaccines, mishnayot,
# Nearest to eight: nine, six, seven, five, four, zero, three, dasyprocta,
# Nearest to has: had, have, was, is, wct, michelob, ursus, circ,
# Nearest to these: some, many, several, all, such, three, operatorname, incest,
# Nearest to over: michelob, edition, agouti, alas, operatorname, pulau, five, mishnayot,
# Nearest to called: and, aorta, vma, disability, crowded, pulau, reversed, nfc,
# Nearest to such: well, many, these, nineties, arin, apologia, bravo, circ,
# Nearest to nine: eight, six, seven, four, five, zero, dasyprocta, agouti,
# Nearest to up: subsidies, them, him, transposed, rotated, stwa, ones, rossetti,
# Nearest to its: their, his, the, her, amazonas, agouti, michelob, pulau,
# Nearest to been: become, be, were, by, was, had, yet, reuptake,
# Nearest to also: which, now, that, kapoor, ursus, often, not, never,
# Nearest to used: ramps, antwerp, circ, primigenius, operatorname, panned, known, dasyprocta,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Average loss at step  62000 :  4.99506185424
# Average loss at step  64000 :  4.83047365433
# Average loss at step  66000 :  4.60335794961
# Average loss at step  68000 :  4.9774666431
# Average loss at step  70000 :  4.9032811352
# Nearest to this: which, it, the, cebus, that, ramps, what, mishnayot,
# Nearest to the: its, their, kapoor, agouti, this, a, dasyprocta, his,
# Nearest to on: in, at, conformations, ursus, upon, beyond, vaccines, within,
# Nearest to eight: nine, six, seven, five, four, three, zero, dasyprocta,
# Nearest to has: had, have, was, is, wct, ursus, hbox, mnr,
# Nearest to these: some, many, several, all, such, cebus, they, operatorname,
# Nearest to over: michelob, five, operatorname, discrepancy, agouti, and, mishnayot, overtime,
# Nearest to called: aorta, disability, vma, UNK, reversed, pulau, nfc, herds,
# Nearest to such: well, these, many, nineties, arin, bravo, known, apologia,
# Nearest to nine: eight, seven, six, five, four, three, zero, dasyprocta,
# Nearest to up: them, subsidies, him, rotated, transposed, liberalize, stwa, rossetti,
# Nearest to its: their, his, the, amazonas, her, agouti, pulau, some,
# Nearest to been: be, become, were, by, was, had, yet, never,
# Nearest to also: which, now, often, never, that, ursus, kapoor, difranco,
# Nearest to used: ramps, antwerp, circ, known, operatorname, dasyprocta, primigenius, seen,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Average loss at step  72000 :  4.74410113204
# Average loss at step  74000 :  4.80482210195
# Average loss at step  76000 :  4.72898939121
# Average loss at step  78000 :  4.79106281185
# Average loss at step  80000 :  4.79219118696
# Nearest to this: which, it, that, cebus, the, what, upanija, operatorname,
# Nearest to the: agouti, their, its, dasyprocta, kapoor, a, six, abet,
# Nearest to on: in, at, conformations, within, ursus, upon, beyond, vaccines,
# Nearest to eight: nine, seven, six, five, four, three, zero, dasyprocta,
# Nearest to has: had, have, was, is, mnr, hbox, ursus, wct,
# Nearest to these: some, many, several, such, all, which, both, cebus,
# Nearest to over: michelob, operatorname, mishnayot, five, overtime, agouti, bugzilla, discrepancy,
# Nearest to called: aorta, vma, disability, reversed, dasyprocta, altenberg, pulau, used,
# Nearest to such: well, these, many, nineties, known, arin, some, bravo,
# Nearest to nine: eight, seven, six, five, four, zero, dasyprocta, agouti,
# Nearest to up: them, him, subsidies, liberalize, transposed, rotated, rossetti, polarized,
# Nearest to its: their, his, the, her, amazonas, agouti, pulau, cebus,
# Nearest to been: become, be, were, by, was, had, yet, arminians,
# Nearest to also: which, now, often, never, ursus, kapoor, it, below,
# Nearest to used: ramps, known, antwerp, seen, operatorname, primigenius, ischemia, circ,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Average loss at step  82000 :  4.77078589511
# Average loss at step  84000 :  4.76081011045
# Average loss at step  86000 :  4.76055531132
# Average loss at step  88000 :  4.75639340413
# Average loss at step  90000 :  4.72082048082
# Nearest to this: which, it, the, cebus, that, another, upanija, operatorname,
# Nearest to the: its, agouti, their, dasyprocta, kapoor, this, a, his,
# Nearest to on: in, at, upon, conformations, within, through, beyond, ursus,
# Nearest to eight: seven, nine, five, six, four, three, zero, dasyprocta,
# Nearest to has: had, have, is, was, mnr, ursus, hbox, having,
# Nearest to these: some, many, several, such, all, which, both, the,
# Nearest to over: michelob, about, only, mishnayot, in, overtime, operatorname, alas,
# Nearest to called: aorta, used, UNK, vma, disability, dasyprocta, shipper, reversed,
# Nearest to such: well, these, many, known, nineties, some, arin, certain,
# Nearest to nine: eight, seven, six, five, four, zero, dasyprocta, three,
# Nearest to up: them, him, subsidies, out, liberalize, transposed, rotated, rossetti,
# Nearest to its: their, his, the, her, amazonas, agouti, pulau, our,
# Nearest to been: be, become, were, by, was, had, yet, never,
# Nearest to also: now, which, often, never, that, ursus, below, it,
# Nearest to used: known, ramps, antwerp, seen, operatorname, ischemia, primigenius, dasyprocta,
# Nearest to five: seven, four, eight, six, three, zero, nine, dasyprocta,
# Average loss at step  92000 :  4.66522181511
# Average loss at step  94000 :  4.72387541091
# Average loss at step  96000 :  4.68295970225
# Average loss at step  98000 :  4.58917731261
# Average loss at step  100000 :  4.69407935214
# Nearest to this: which, it, the, cebus, that, mishnayot, some, operatorname,
# Nearest to the: its, agouti, their, this, a, dasyprocta, kapoor, his,
# Nearest to on: in, upon, at, within, conformations, vaccines, through, ursus,
# Nearest to eight: seven, six, nine, five, four, three, zero, dasyprocta,
# Nearest to has: had, have, was, is, mnr, ursus, hbox, having,
# Nearest to these: some, many, several, such, all, which, they, both,
# Nearest to over: michelob, mishnayot, operatorname, bugzilla, about, only, contaminated, overtime,
# Nearest to called: aorta, used, disability, shipper, vma, UNK, considered, clockwork,
# Nearest to such: well, these, many, known, arin, some, nineties, certain,
# Nearest to nine: eight, seven, six, five, zero, four, three, dasyprocta,
# Nearest to up: them, him, out, subsidies, liberalize, transposed, rotated, polarized,
# Nearest to its: their, his, the, her, amazonas, agouti, our, some,
# Nearest to been: become, be, was, were, by, had, never, yet,
# Nearest to also: now, which, often, never, ursus, that, kapoor, below,
# Nearest to used: known, antwerp, seen, ramps, designed, operatorname, ischemia, primigenius,
# Nearest to five: four, seven, three, six, eight, two, nine, dasyprocta,

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

    plt.savefig(filename)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
