# %% [markdown]
# # Word2Vec Tutorial

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


words = read_data(filename)
print('Data size', len(words))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
def build_dataset(words, vocabulary_size):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3081, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
dictionary = dict()
for word, _ in count:
    dictionary[word] = len(dictionary)
data = list()
unk_count = 0
for word in words:
    if word in dictionary:
        index = dictionary[word]
    else:
        index = 0  # dictionary['UNK']
        unk_count += 1
    data.append(index)
count[0][1] = unk_count
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
del words  # Hint to reduce memory.

# %% [markdown]
# ## dictionary :dict타입 '단어': 인덱스값
# ## data : words배열에서 각 워드의 인덱스값
# ## count : 가장높은 빈도수로나온 단어,몇번 나왔는지에 대한 튜플로구성된 리스트

# %%
del  count

# %%
data_index = 0
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span): # span 3
        buffer.append(data[data_index]) 
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips): # batchsize//numskips = 4
        target = skip_window  # target label at the center of the buffer 1
        targets_to_avoid = [skip_window] # tarkets_to_avoid = [1]
        for j in range(num_skips): # 2
            while target in targets_to_avoid: #1 in [1]
                target = random.randint(0, span - 1)  # target =  0
            targets_to_avoid.append(target)  # [1,0]
            batch[i * num_skips + j] = buffer[skip_window] # 
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# %%
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
          '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5244 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=embed,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  274.481689453
# Nearest to most: rims, beers, grids, cond, compressor, ponds, rain, zant,
# Nearest to other: wayne, marlon, abrogated, betting, satrapy, billing, krugerrand, banzer,
# Nearest to used: abi, hiragana, development, housed, tracking, archon, lubavitch, bowlers,
# Nearest to after: amadeus, hyped, landlords, brixton, seigenthaler, horde, caver, premiership,
# Nearest to the: installing, pago, helios, kao, genocides, reemergence, executing, nunavut,
# Nearest to it: induction, knut, johns, pe, amassed, deptford, gorillas, madhu,
# Nearest to if: bentine, commissioners, sibilants, appleton, fagan, slovenes, infrequent, hierarchy,
# Nearest to see: synchronic, indie, kaifu, maid, extras, massachusetts, respiration, cryptids,
# Nearest to th: gustaf, snk, for, cooler, sahih, psychedelics, tests, pardons,
# Nearest to often: intestinal, sinhalese, indefinitely, recipe, enrique, bitchx, kingdom, upanija,
# Nearest to time: officiate, mohs, rancher, turboprops, mutants, leftrightarrow, blitzkrieg, scheduling,
# Nearest to by: subjected, obiang, muscat, encoded, hallucinogen, mao, glorified, nonempty,
# Nearest to two: uefa, confuses, centre, cession, fermented, painful, therapeutic, lifetimes,
# Nearest to d: micronesia, trapezohedron, purporting, antoni, marija, headlines, cultivation, sideways,
# Nearest to world: ghostly, behaving, sgi, retrieving, krona, tome, crumbs, robots,
# Nearest to his: pleated, lupin, delphi, corrupting, phil, ged, pantera, programming,
# Average loss at step  2000 :  114.105002396
# Average loss at step  4000 :  52.8311674914
# Average loss at step  6000 :  33.1428418226
# Average loss at step  8000 :  23.5107032251
# Average loss at step  10000 :  17.6335286976
# Nearest to most: beers, is, rims, were, mouth, socio, orbit, rare,
# Nearest to other: wayne, aberdeenshire, knew, df, lost, spots, persia, duties,
# Nearest to used: development, ramsey, nucleus, phi, altitude, and, numerous, hyacinthus,
# Nearest to after: agave, bourgeois, species, political, din, ip, grandparents, alkene,
# Nearest to the: one, nine, three, molinari, aberdeenshire, agave, fairbanks, gland,
# Nearest to it: induction, to, characterised, nine, candidates, existing, amassed, poverty,
# Nearest to if: and, of, by, nine, on, UNK, from, with,
# Nearest to see: two, UNK, nine, coke, agave, phi, archie, zero,
# Nearest to th: the, UNK, and, fao, bckgr, this, tunnel, phi,
# Nearest to often: ada, these, intestinal, hispanic, silver, not, kingdom, milne,
# Nearest to time: collection, the, astronomers, austin, islamic, canaris, his, electric,
# Nearest to by: was, in, canaris, and, are, subjected, simple, tubing,
# Nearest to two: agave, fermented, length, centre, lambar, kenya, mathbf, mandate,
# Nearest to d: in, micronesia, first, connection, borman, phi, prospect, branden,
# Nearest to world: a, the, alkanes, robots, albedo, thoughts, brick, concert,
# Nearest to his: phil, UNK, unprotected, delphi, programming, phi, mulcahy, j,
# Average loss at step  12000 :  14.0129417548
# Average loss at step  14000 :  11.643432899
# Average loss at step  16000 :  9.94912988591
# Average loss at step  18000 :  8.35089756894
# Average loss at step  20000 :  8.11919760883
# Nearest to most: is, were, was, beers, agouti, and, had, socio,
# Nearest to other: wayne, aberdeenshire, knew, hampshire, agouti, socrates, inconsistent, df,
# Nearest to used: and, circ, abi, altitude, architects, phi, archon, converting,
# Nearest to after: agave, after, giovanni, angelus, political, ip, bourgeois, orbits,
# Nearest to the: one, three, dasyprocta, four, six, eight, operatorname, nine,
# Nearest to it: induction, to, agouti, wattle, characterised, contented, is, johns,
# Nearest to if: and, on, of, by, at, from, with, nine,
# Nearest to see: two, operatorname, dasyprocta, agouti, nine, three, eight, seven,
# Nearest to th: the, this, agouti, quit, bckgr, dasyprocta, fao, his,
# Nearest to often: not, these, it, operatorname, hispanic, intestinal, ada, apatosaurus,
# Nearest to time: the, his, operatorname, dasyprocta, their, circ, alien, explicit,
# Nearest to by: was, are, were, has, agouti, by, be, for,
# Nearest to two: agave, and, fermented, however, length, for, before, schismatic,
# Nearest to d: trapezohedron, micronesia, first, in, antoni, capacitor, connection, prospect,
# Nearest to world: the, a, it, alkanes, dasyprocta, concert, acacia, operatorname,
# Nearest to his: delphi, unprotected, programming, phil, phi, trough, simpler, UNK,
# Average loss at step  22000 :  6.93878562093
# Average loss at step  24000 :  6.8567235471
# Average loss at step  26000 :  6.81970834816
# Average loss at step  28000 :  6.43240588117
# Average loss at step  30000 :  5.90638196838
# Nearest to most: were, is, was, have, phenomenology, agouti, circ, denied,
# Nearest to other: wayne, consoles, reddy, aberdeenshire, knew, stella, hampshire, agouti,
# Nearest to used: and, circ, operatorname, altitude, phi, abi, agouti, converting,
# Nearest to after: after, wideawake, and, agave, musa, angelus, orbits, contented,
# Nearest to the: four, three, six, one, eight, dasyprocta, five, seven,
# Nearest to it: induction, to, agouti, would, wattle, characterised, contented, johns,
# Nearest to if: at, on, and, from, with, by, of, nine,
# Nearest to see: two, dasyprocta, operatorname, four, seven, eight, three, agouti,
# Nearest to th: the, bos, birkenau, agouti, this, bckgr, dasyprocta, apatosaurus,
# Nearest to often: it, these, not, operatorname, they, also, said, he,
# Nearest to time: the, his, their, operatorname, hamas, dasyprocta, zionists, a,
# Nearest to by: was, are, has, were, agouti, by, be, as,
# Nearest to two: before, from, however, for, agave, and, while, fermented,
# Nearest to d: trapezohedron, first, toed, micronesia, capacitor, sockets, antoni, buchanan,
# Nearest to world: the, it, which, a, dasyprocta, alkanes, operatorname, that,
# Nearest to his: delphi, unprotected, programming, trough, phil, phi, UNK, simpler,
# Average loss at step  32000 :  5.9309870342
# Average loss at step  34000 :  5.67611861563
# Average loss at step  36000 :  5.77469296968
# Average loss at step  38000 :  5.50128332639
# Average loss at step  40000 :  5.25915898335
# Nearest to most: were, is, have, was, agouti, circ, denied, zero,
# Nearest to other: wayne, aberdeenshire, reddy, agouti, some, knew, consoles, banzer,
# Nearest to used: and, circ, operatorname, altitude, converting, or, she, agouti,
# Nearest to after: after, wideawake, and, but, musa, latium, agave, ou,
# Nearest to the: one, three, four, five, eight, six, seven, dasyprocta,
# Nearest to it: would, to, induction, can, agouti, must, wattle, characterised,
# Nearest to if: at, from, on, and, of, zero, circ, nine,
# Nearest to see: two, eight, four, operatorname, six, seven, three, dasyprocta,
# Nearest to th: the, albury, agouti, birkenau, bos, dasyprocta, bckgr, this,
# Nearest to often: it, these, they, not, he, also, which, she,
# Nearest to time: the, their, his, trombones, operatorname, dasyprocta, hamas, a,
# Nearest to by: was, are, has, were, agouti, withdraw, as, azad,
# Nearest to two: before, however, from, agave, where, while, three, leeds,
# Nearest to d: trapezohedron, first, voltaic, sockets, capacitor, more, akita, toed,
# Nearest to world: the, which, it, that, a, one, dasyprocta, thoughts,
# Nearest to his: UNK, delphi, trough, programming, phil, unprotected, phi, simpler,
# Average loss at step  42000 :  5.36213854361
# Average loss at step  44000 :  5.23668949544
# Average loss at step  46000 :  5.2515513376
# Average loss at step  48000 :  5.23829746234
# Average loss at step  50000 :  4.98776705194
# Nearest to most: were, is, have, agouti, eight, three, circ, was,
# Nearest to other: two, buff, wayne, reddy, some, knew, agouti, aberdeenshire,
# Nearest to used: and, circ, however, or, altitude, six, when, operatorname,
# Nearest to after: but, after, wideawake, circ, agave, and, recitative, musa,
# Nearest to the: three, one, four, six, five, seven, dasyprocta, eight,
# Nearest to it: would, can, to, must, induction, may, agouti, could,
# Nearest to if: at, from, on, and, of, for, with, nine,
# Nearest to see: two, four, seven, three, six, eight, operatorname, five,
# Nearest to th: the, bos, albury, five, birkenau, bckgr, this, agouti,
# Nearest to often: it, they, these, he, not, which, operatorname, also,
# Nearest to time: their, the, his, gigantopithecus, operatorname, her, trombones, similar,
# Nearest to by: was, are, has, were, eight, be, wrongful, agouti,
# Nearest to two: before, however, for, six, from, while, three, seven,
# Nearest to d: trapezohedron, more, sockets, generational, purporting, voltaic, fouls, capacitor,
# Nearest to world: which, it, the, that, some, dasyprocta, thoughts, a,
# Nearest to his: UNK, chanter, delphi, trough, and, unprotected, phi, phil,
# Average loss at step  52000 :  5.03861553109
# Average loss at step  54000 :  5.18192673862
# Average loss at step  56000 :  5.04868219757
# Average loss at step  58000 :  5.05458387852
# Average loss at step  60000 :  4.94654697073
# Nearest to most: were, is, have, agouti, be, was, holly, circ,
# Nearest to other: two, some, these, three, buff, ursus, reddy, wayne,
# Nearest to used: circ, ursus, and, or, however, operatorname, ursinus, when,
# Nearest to after: but, after, wideawake, that, circ, recitative, agave, while,
# Nearest to the: three, four, one, six, five, dasyprocta, eight, ursus,
# Nearest to it: would, can, must, to, may, thibetanus, could, induction,
# Nearest to if: at, on, from, during, ursus, under, and, of,
# Nearest to see: two, four, six, three, operatorname, five, eight, ursus,
# Nearest to th: the, albury, birkenau, agouti, bos, ursus, bckgr, any,
# Nearest to often: it, they, these, he, which, operatorname, not, she,
# Nearest to time: their, his, the, gigantopithecus, her, ursus, operatorname, trombones,
# Nearest to by: was, are, has, ursus, withdraw, eight, agouti, were,
# Nearest to two: before, however, while, from, in, at, six, where,
# Nearest to d: trapezohedron, more, ursus, bohdan, kodiak, sockets, akita, first,
# Nearest to world: which, it, that, the, ursus, wct, dasyprocta, some,
# Nearest to his: UNK, chanter, delphi, currently, trough, unprotected, programming, phil,
# Average loss at step  62000 :  5.03199350739
# Average loss at step  64000 :  4.8390295738
# Average loss at step  66000 :  4.59159260333
# Average loss at step  68000 :  4.98127308691
# Average loss at step  70000 :  4.89536538887
# Nearest to most: were, is, have, was, be, agouti, although, leontopithecus,
# Nearest to other: some, these, thaler, two, ursus, any, buff, agouti,
# Nearest to used: and, circ, however, ursus, although, when, or, microcebus,
# Nearest to after: but, after, while, wideawake, circ, that, recitative, and,
# Nearest to the: three, six, four, five, one, eight, dasyprocta, seven,
# Nearest to it: would, can, must, may, could, to, thibetanus, induction,
# Nearest to if: at, ursus, and, microcebus, during, circ, on, under,
# Nearest to see: six, four, two, five, eight, three, operatorname, seven,
# Nearest to th: the, albury, any, microcebus, bos, ursus, agouti, bckgr,
# Nearest to often: it, they, these, he, upanija, she, which, said,
# Nearest to time: their, his, the, her, gigantopithecus, ursus, operatorname, overline,
# Nearest to by: was, are, has, ursus, leontopithecus, mitral, mico, withdraw,
# Nearest to two: before, however, while, from, when, during, in, at,
# Nearest to d: more, trapezohedron, kodiak, ursus, sockets, generational, purporting, bohdan,
# Nearest to world: which, it, the, that, wct, ursus, amazonas, dasyprocta,
# Nearest to his: UNK, chanter, trough, currently, delphi, unprotected, programming, ursus,
# Average loss at step  72000 :  4.76291435182
# Average loss at step  74000 :  4.81755232704
# Average loss at step  76000 :  4.72869000065
# Average loss at step  78000 :  4.79386712787
# Average loss at step  80000 :  4.7931435889
# Nearest to most: were, is, have, be, agouti, leontopithecus, was, seven,
# Nearest to other: some, these, two, both, thaler, buff, many, ursus,
# Nearest to used: and, however, circ, ursus, when, although, ursinus, or,
# Nearest to after: but, that, while, after, circ, wideawake, recitative, although,
# Nearest to the: three, six, four, five, one, seven, dasyprocta, eight,
# Nearest to it: would, can, must, may, could, might, to, thibetanus,
# Nearest to if: at, during, from, microcebus, ursus, apatosaurus, and, under,
# Nearest to see: seven, six, two, four, operatorname, five, three, dasyprocta,
# Nearest to th: the, albury, any, bckgr, wct, bos, microsite, ursus,
# Nearest to often: it, they, these, he, which, she, said, upanija,
# Nearest to time: their, his, the, her, ursus, gigantopithecus, operatorname, trombones,
# Nearest to by: was, are, has, leontopithecus, ursus, mitral, withdraw, became,
# Nearest to two: before, from, when, however, during, while, in, at,
# Nearest to d: more, trapezohedron, many, some, sockets, generational, ursus, kodiak,
# Nearest to world: which, it, the, that, wct, ursus, some, swaps,
# Nearest to his: chanter, trough, delphi, currently, acacia, ursus, equine, seminal,
# Average loss at step  82000 :  4.75997404122
# Average loss at step  84000 :  4.74571032119
# Average loss at step  86000 :  4.76803818059
# Average loss at step  88000 :  4.74436129582
# Average loss at step  90000 :  4.79420552528
# Nearest to most: were, have, is, leontopithecus, be, although, eight, while,
# Nearest to other: some, both, these, thaler, any, two, agouti, ursus,
# Nearest to used: and, however, circ, ursus, although, when, which, or,
# Nearest to after: but, that, while, circ, wideawake, although, dasyprocta, recitative,
# Nearest to the: three, four, five, one, six, seven, dasyprocta, eight,
# Nearest to it: would, can, may, must, could, might, to, should,
# Nearest to if: during, at, within, under, on, from, ursus, microcebus,
# Nearest to see: four, two, three, seven, five, eight, six, operatorname,
# Nearest to th: the, albury, bckgr, any, ursus, birkenau, another, microcebus,
# Nearest to often: it, they, he, these, said, she, upanija, which,
# Nearest to time: their, his, the, her, ursus, gigantopithecus, operatorname, trombones,
# Nearest to by: was, has, are, leontopithecus, ursus, mitral, seems, became,
# Nearest to two: before, when, during, from, while, however, at, agave,
# Nearest to d: more, many, trapezohedron, some, sockets, konerko, generational, ursus,
# Nearest to world: which, it, the, wct, ursus, that, some, amazonas,
# Nearest to his: chanter, UNK, trough, acacia, ursus, delphi, equine, thaler,
# Average loss at step  92000 :  4.6737416153
# Average loss at step  94000 :  4.71759739208
# Average loss at step  96000 :  4.69114785743
# Average loss at step  98000 :  4.60004121619
# Average loss at step  100000 :  4.69602852678
# Nearest to most: were, have, is, although, leontopithecus, including, be, while,
# Nearest to other: some, these, both, many, any, thaler, agouti, ursus,
# Nearest to used: however, and, circ, although, ursus, which, or, ursinus,
# Nearest to after: but, that, while, although, circ, wideawake, after, dasyprocta,
# Nearest to the: three, four, five, six, one, dasyprocta, seven, eight,
# Nearest to it: would, can, may, must, could, might, should, to,
# Nearest to if: during, at, within, from, under, on, ursus, microcebus,
# Nearest to see: two, four, operatorname, six, five, seven, dasyprocta, eight,
# Nearest to th: the, another, albury, any, microsite, ursus, microcebus, operatorname,
# Nearest to often: it, they, he, said, she, these, which, upanija,
# Nearest to time: their, his, the, her, ursus, gigantopithecus, operatorname, trombones,
# Nearest to by: was, has, are, ursus, leontopithecus, mitral, became, seems,
# Nearest to two: before, when, during, while, from, however, at, in,
# Nearest to d: more, many, some, sockets, trapezohedron, konerko, ursus, roper,
# Nearest to world: which, it, the, wct, ursus, that, some, apatosaurus,
# Nearest to his: chanter, trough, acacia, UNK, exported, equine, trapezohedron, ursus,
